# %% [markdown]
# # Analise - População de Rua

# %% [markdown]
# ### Importações

# %%
#Pandas para manipulação de dataframe:
import pandas as pd

# %%
#Bibliotecas para plotagem de gráficos:
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
#Folium pra fazer peripécia no gráfico ;)
import folium

# %% [markdown]
# ### Manipulação da Tabela

# %% [markdown]
# Importação de dados

# %%
#importando os dados de população de Rua:
df_poprua = pd.read_excel(r'D:\Estudo\Extensão - Ciência de Dados\Base do Censo PopRua 2020 (anonimizada).xlsx')

#importando os dados do município do Rio:
muni_rj = gpd.read_file(r'D:\Estudo\Extensão - Ciência de Dados\Munipios\muni_rj.json', driver="GeoJSON")
# Out:
# C:\Users\amori\anaconda3\envs\datamind\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# Dados de população de Rua

# %%
#Tabela:
display(df_poprua)
# Out:
#                        Chave_única                            ID  \
# 0                        Rua_10000                         Rua_2
# 1                        Rua_10001                         Rua_5
# 2                        Rua_10002                         Rua_6
# 3                        Rua_10003                         Rua_8
# 4                        Rua_10004                         Rua_9
# ...                            ...                           ...
# 7267  Unidade de acolhimento_17267  Comunidades Terapêuticas_262
# 7268  Unidade de acolhimento_17268  Comunidades Terapêuticas_263
# 7269  Unidade de acolhimento_17269  Comunidades Terapêuticas_264
# 7270  Unidade de acolhimento_17270  Comunidades Terapêuticas_265
# 7271  Unidade de acolhimento_17271  Comunidades Terapêuticas_266
#
#      Rua_Acolhimento  Local da coleta de dados  \
# 0                Rua                       Rua
# 1                Rua                       Rua
# 2                Rua                       Rua
# 3                Rua                       Rua
# 4                Rua                       Rua
# ...              ...                       ...
# 7267       Acolhidos  Comunidades terapêuticas
# 7268       Acolhidos  Comunidades terapêuticas
# 7269       Acolhidos  Comunidades terapêuticas
# 7270       Acolhidos  Comunidades terapêuticas
# 7271       Acolhidos  Comunidades terapêuticas
#
#            Unidade de Acolhimento/US      Método Instrumento de coleta  \
# 0                                NaN  Entrevista   Questionário normal
# 1                                NaN  Entrevista   Questionário normal
# 2                                NaN  Entrevista   Questionário normal
# 3                                NaN  Entrevista   Questionário normal
# 4                                NaN  Entrevista   Questionário normal
# ...                              ...         ...                   ...
# 7267  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7268  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7269  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7270  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7271  Instituto Revivendo com Cristo  Observação   Questionário normal
#
#           Cod_setor          Turno        Data  ... Motivo_local_uso_droga  \
# 0            D1S21M          Manhã  26/10/2020  ...          Não se aplica
# 1            D1S20M          Manhã  26/10/2020  ...          Não se aplica
# 2            D1S20M          Manhã  26/10/2020  ...          Não se aplica
# 3            D1S20M          Manhã  26/10/2020  ...          Não se aplica
# 4            D1S20M          Manhã  26/10/2020  ...          Não se aplica
# ...             ...            ...         ...  ...                    ...
# 7267  Não se aplica  Não se aplica         NaN  ...          Não se aplica
# 7268  Não se aplica  Não se aplica         NaN  ...          Não se aplica
# 7269  Não se aplica  Não se aplica         NaN  ...          Não se aplica
# 7270  Não se aplica  Não se aplica         NaN  ...          Não se aplica
# 7271  Não se aplica  Não se aplica         NaN  ...          Não se aplica
#
#       Necessidade_sair_situação  Área de Planejamento Nome do Bairro  \
# 0         Não quero sair da rua                  AP 5      Paciência
# 1                       Família                  AP 5   Campo Grande
# 2                       Moradia                  AP 5   Campo Grande
# 3         Não quero sair da rua                  AP 5   Campo Grande
# 4                         Outro                  AP 5   Campo Grande
# ...                         ...                   ...            ...
# 7267              Não se aplica                  AP 5      Guaratiba
# 7268              Não se aplica                  AP 5      Guaratiba
# 7269              Não se aplica                  AP 5      Guaratiba
# 7270              Não se aplica                  AP 5      Guaratiba
# 7271              Não se aplica                  AP 5      Guaratiba
#
#      Código da RP                  RP Código da RA Região Administrativa  \
# 0             5.3    5.3 - Santa Cruz           19      XIX - SANTA CRUZ
# 1             5.2  5.2 - Campo Grande           18  XVIII - CAMPO GRANDE
# 2             5.2  5.2 - Campo Grande           18  XVIII - CAMPO GRANDE
# 3             5.2  5.2 - Campo Grande           18  XVIII - CAMPO GRANDE
# 4             5.2  5.2 - Campo Grande           18  XVIII - CAMPO GRANDE
# ...           ...                 ...          ...                   ...
# 7267          5.4     5.4 - Guaratiba           26      XXVI - GUARATIBA
# 7268          5.4     5.4 - Guaratiba           26      XXVI - GUARATIBA
# 7269          5.4     5.4 - Guaratiba           26      XXVI - GUARATIBA
# 7270          5.4     5.4 - Guaratiba           26      XXVI - GUARATIBA
# 7271          5.4     5.4 - Guaratiba           26      XXVI - GUARATIBA
#
#           Faixa etária Classificação idade
# 0              18 a 30              Adulto
# 1              31 a 49              Adulto
# 2              31 a 49              Adulto
# 3              50 a 59              Adulto
# 4              31 a 49              Adulto
# ...                ...                 ...
# 7267  Não identificada      Sem informação
# 7268  Não identificada      Sem informação
# 7269  Não identificada      Sem informação
# 7270  Não identificada      Sem informação
# 7271  Não identificada      Sem informação
#
# [7272 rows x 136 columns]

# %%
#Puxar as colunas aqui, pra ter uma vizualização melhor dos elementos estudados:
print(df_poprua.info('columns'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7272 entries, 0 to 7271
# Data columns (total 136 columns):
#  #    Column                                                                                               Dtype
# ---   ------                                                                                               -----
#  0    Chave_única                                                                                          object
#  1    ID                                                                                                   object
#  2    Rua_Acolhimento                                                                                      object
#  3    Local da coleta de dados                                                                             object
#  4    Unidade de Acolhimento/US                                                                            object
#  5    Método                                                                                               object
#  6    Instrumento de coleta                                                                                object
#  7    Cod_setor                                                                                            object
#  8    Turno                                                                                                object
#  9    Data                                                                                                 object
#  10   Bairro                                                                                               object
#  11   Latitude                                                                                             float64
#  12   Longitude                                                                                            float64
#  13   Situação_entrevista                                                                                  object
#  14   Motivo_situação                                                                                      object
#  15   Idade                                                                                                int64
#  16   Faixa etária observada                                                                               object
#  17   Dormiu_rua                                                                                           object
#  18   Responder_questionário                                                                               object
#  19   Questionário de Observação                                                                           object
#  20   Sexo                                                                                                 object
#  21   Gênero                                                                                               object
#  22   Cor_raça                                                                                             object
#  23   Caminhar ou subir degraus                                                                            object
#  24   Enxergar, mesmo que com óculos ou lentes de contato                                                  object
#  25   Ouvir, mesmo que com aparelho                                                                        object
#  26   Possui alguma deficiência mental? Dificuldade em aprender, trabalhar, se comunicar com outros etc.   object
#  27   Não possui nenhuma deficiência                                                                       object
#  28   NS/NR                                                                                                object
#  29   Certidão de Nascimento                                                                               object
#  30   CPF                                                                                                  object
#  31   Carteira de Identidade                                                                               object
#  32   Carteira de Trabalho                                                                                 object
#  33   Título de Eleitor                                                                                    object
#  34   Passaporte                                                                                           object
#  35   RED                                                                                                  object
#  36   Naturalidade                                                                                         object
#  37   Estado                                                                                               object
#  38   Município                                                                                            object
#  39   Voltar_cidade_natal                                                                                  object
#  40   Contato_família                                                                                      object
#  41   Contato_família_complemento                                                                          object
#  42   Dorme_rua_acolhimento                                                                                object
#  43   Há_crianças                                                                                          object
#  44   Residência_fixa                                                                                      object
#  45   Residência_fixa_complemento                                                                          object
#  46   Dormiu_rua_últimos_30dias                                                                            object
#  47   Motivo_dormir_rua                                                                                    object
#  48   Tempo_rua_RJ                                                                                         object
#  49   Rua_início_coronavírus                                                                               object
#  50   Por_quê                                                                                              object
#  51   Ajuda_pandemia                                                                                       object
#  52   Auxílio_emergencial                                                                                  object
#  53   Alimentos                                                                                            object
#  54   Itens_higiene_pessoal                                                                                object
#  55   Máscaras_proteção                                                                                    object
#  56   Oferta_lugares_para_higiene                                                                          object
#  57   NS_NR                                                                                                object
#  58   Local_anterior_dormitório                                                                            object
#  59   Local_dormitório                                                                                     object
#  60   Dormiu_rua_maioria_últimos_7dias                                                                     object
#  61   Lugar_7_dias                                                                                         object
#  62   Bairro_7_dias                                                                                        object
#  63   Dormiu_abrigo_prefeitura                                                                             object
#  64   Dormiu_abrigo_quanto_tempo                                                                           object
#  65   Dificuldade_abrigo                                                                                   object
#  66   Onde_estava_antes_Unidade_acolhimento                                                                object
#  67   Abrigos_apresentam_problemas                                                                         object
#  68   Principal_problema_abrigo                                                                            object
#  69   CRAS                                                                                                 object
#  70   CREAS                                                                                                object
#  71   CENTRO POP                                                                                           object
#  72   Equipe de Abordagem Social                                                                           object
#  73   Conselho Tutelar                                                                                     object
#  74   Unidade de Acolhimento                                                                               object
#  75   Central de Recepção                                                                                  object
#  76   Hotel                                                                                                object
#  77   Defensoria Pública                                                                                   object
#  78   Não foi atendido por nenhuma instituição                                                             object
#  79   NS/NR.1                                                                                              object
#  80   Dificuldades_atendimentos_serviços                                                                   object
#  81   Atividade_remunerada                                                                                 object
#  82   Atividade_realizada                                                                                  object
#  83   Recebe outras fontes de renda                                                                        object
#  84   Bolsa Família                                                                                        object
#  85   Auxílio Emergencial                                                                                  object
#  86   Benefício de Prestação Continuada                                                                    object
#  87   Aposentadoria/Pensão                                                                                 object
#  88   Auxílio Doença                                                                                       object
#  89   Auxílio Habitacional Temporário                                                                      object
#  90   Outros                                                                                               object
#  91   Não recebe nenhum auxílio                                                                            object
#  92   NS/NR.2                                                                                              object
#  93   Grávidez                                                                                             object
#  94   Acompanhamento_pré_natal                                                                             object
#  95   Diabetes                                                                                             object
#  96   Pressão alta/ problemas no coração                                                                   object
#  97   HIV/ AIDS                                                                                            object
#  98   Sífilis ou outras Infecções Sexualmente Transmissíveis (IST's)                                       object
#  99   Asma/ Bronquite/Pneumonia                                                                            object
#  100  Tuberculose                                                                                          object
#  101  Câncer/ Tumores                                                                                      object
#  102  Hepatite                                                                                             object
#  103  Transtorno mental/Epilepsia                                                                          object
#  104  Lepra ou outras Doenças de pele                                                                      object
#  105  Infecção Urinária                                                                                    object
#  106  Ferimentos, fraturas ou outros traumas físicos                                                       object
#  107  Unidade_saúde_procura                                                                                object
#  108  Sabe_ler_escrever                                                                                    object
#  109  Frequentou_escola                                                                                    object
#  110  Escolaridade                                                                                         object
#  111  Escolaridade_corrigida                                                                               object
#  112  Uso de pelo menos uma droga                                                                          object
#  113  Tabaco                                                                                               object
#  114  Álcool                                                                                               object
#  115  Maconha/Haxixe                                                                                       object
#  116  Crack/Similares                                                                                      object
#  117  Cocaína                                                                                              object
#  118  Inalantes/Cola/Solvente/Tiner                                                                        object
#  119  Frequência_tabaco                                                                                    object
#  120  Frequência_Álcool                                                                                    object
#  121  Frequência_Maconha/Haxixe                                                                            object
#  122  Frequência_Crack/Similares                                                                           object
#  123  Frequência_Cocaína                                                                                   object
#  124  Frequência_Inalantes/Cola/Solvente/Tiner                                                             object
#  125  Motivo_Droga                                                                                         object
#  126  Motivo_local_uso_droga                                                                               object
#  127  Necessidade_sair_situação                                                                            object
#  128  Área de Planejamento                                                                                 object
#  129  Nome do Bairro                                                                                       object
#  130  Código da RP                                                                                         float64
#  131  RP                                                                                                   object
#  132  Código da RA                                                                                         int64
#  133  Região Administrativa                                                                                object
#  134  Faixa etária                                                                                         object
#  135  Classificação idade                                                                                  object
# dtypes: float64(3), int64(2), object(131)
# memory usage: 7.5+ MB
# None

# %% [markdown]
# ### Correções

# %%
#Valores nulos:
Q_Nan = df_poprua.isnull().sum().sum()
print("A quantidade de NaN é {}".format(Q_Nan))
if Q_Nan == 0:
    print("Normalizado")
else:
    print("Ainda há NaN na tabela!")
# Out:
# A quantidade de NaN é 12726
# Ainda há NaN na tabela!

# %%
#Definindo as tabelas que tem dados Nulos:
enulo=df_poprua.isnull().sum()
display(enulo.head(50))

#Corrigindo:
df_poprua['Unidade de Acolhimento/US'].fillna('Sem Resposta', inplace = True)
df_poprua['Data'].fillna('Sem Resposta', inplace = True)
df_poprua['Abrigos_apresentam_problemas'].fillna('Sem Resposta', inplace = True)
df_poprua['Onde_estava_antes_Unidade_acolhimento'].fillna('Sem Resposta', inplace = True)

#Checando os dados tratados:
Q_Nan_2 = df_poprua.isnull().sum().sum()
print("A quantidade de NaN é {}".format(Q_Nan_2))
if Q_Nan_2 == 0:
    print("Normalizado")
else:
    print("Ainda há NaN na tabela!")
# Out:
# Chave_única                                                                                               0
# ID                                                                                                        0
# Rua_Acolhimento                                                                                           0
# Local da coleta de dados                                                                                  0
# Unidade de Acolhimento/US                                                                              5435
# Método                                                                                                    0
# Instrumento de coleta                                                                                     0
# Cod_setor                                                                                                 0
# Turno                                                                                                     0
# Data                                                                                                   1837
# Bairro                                                                                                    0
# Latitude                                                                                                  0
# Longitude                                                                                                 0
# Situação_entrevista                                                                                       0
# Motivo_situação                                                                                           0
# Idade                                                                                                     0
# Faixa etária observada                                                                                    0
# Dormiu_rua                                                                                                0
# Responder_questionário                                                                                    0
# Questionário de Observação                                                                                0
# Sexo                                                                                                      0
# Gênero                                                                                                    0
# Cor_raça                                                                                                  0
# Caminhar ou subir degraus                                                                                 0
# Enxergar, mesmo que com óculos ou lentes de contato                                                       0
# Ouvir, mesmo que com aparelho                                                                             0
# Possui alguma deficiência mental? Dificuldade em aprender, trabalhar, se comunicar com outros etc.        0
# Não possui nenhuma deficiência                                                                            0
# NS/NR                                                                                                     0
# Certidão de Nascimento                                                                                    0
# CPF                                                                                                       0
# Carteira de Identidade                                                                                    0
# Carteira de Trabalho                                                                                      0
# Título de Eleitor                                                                                         0
# Passaporte                                                                                                0
# RED                                                                                                       0
# Naturalidade                                                                                              0
# Estado                                                                                                    0
# Município                                                                                                 0
# Voltar_cidade_natal                                                                                       0
# Contato_família                                                                                           0
# Contato_família_complemento                                                                               0
# Dorme_rua_acolhimento                                                                                     0
# Há_crianças                                                                                               0
# Residência_fixa                                                                                           0
# Residência_fixa_complemento                                                                               0
# Dormiu_rua_últimos_30dias                                                                                 0
# Motivo_dormir_rua                                                                                         0
# Tempo_rua_RJ                                                                                              0
# Rua_início_coronavírus                                                                                    0
# dtype: int64
# A quantidade de NaN é 0
# Normalizado

# %% [markdown]
# ### Contagens

# %%
#Tabela em porcentagem
df_poprua['Município'].value_counts(dropna = False, sort = True, ascending = False, normalize = True).head(50) *100
# Out:
# Não se aplica                  91.350385
# Duque de Caxias                 1.787679
# NS/NR                           1.333883
# Nova Iguaçu                     0.907591
# Niterói                         0.563806
# São João de Meriti              0.412541
# Belford Roxo                    0.398790
# Nilópolis                       0.288779
# Campos dos Goytacazes           0.288779
# Petrópolis                      0.233773
# São Gonçalo                     0.233773
# Queimados                       0.178768
# Nova Friburgo                   0.151265
# Mesquita                        0.137514
# Magé                            0.137514
# Itaguaí                         0.110011
# Macaé                           0.110011
# Angra dos Reis                  0.096260
# Cabo Frio                       0.096260
# Volta Redonda                   0.096260
# Três Rios                       0.082508
# Araruama                        0.068757
# Barra Mansa                     0.068757
# Resende                         0.068757
# Japeri                          0.055006
# Barra do Piraí                  0.055006
# Itaboraí                        0.055006
# Maricá                          0.055006
# Bom Jesus do Itabapoana         0.055006
# São Pedro da Aldeia             0.041254
# Itaperuna                       0.041254
# Teresópolis                     0.041254
# Seropédica                      0.041254
# Saquarema                       0.041254
# Rio Claro                       0.041254
# Mangaratiba                     0.027503
# Rio das Ostras                  0.027503
# Paracambi                       0.027503
# Miracema                        0.013751
# Carapebus                       0.013751
# Rio das Flores                  0.013751
# Vassouras                       0.013751
# Rio Bonito                      0.013751
# Santo Antônio de Pádua          0.013751
# Engenheiro Paulo de Frontin     0.013751
# Arraial do Cabo                 0.013751
# Miguel Pereira                  0.013751
# Piraí                           0.013751
# São João da Barra               0.013751
# Guapimirim                      0.013751
# Name: Município, dtype: float64

# %% [markdown]
# ### Graficos e Plotagens

# %% [markdown]
# Plotagens simple com o Pandas

# %%
#Gráfico de barras horizontais:
plt.show(df_poprua['Escolaridade'].value_counts().plot(kind = 'barh'))

# %%
#Gráfico de linha:
plt.show(df_poprua['Rua_início_coronavírus'].value_counts().plot(kind = 'line'))

# %%
#Gráfico de setores:
plt.show(df_poprua['Sexo'].value_counts().plot(kind = 'pie', autopct = '%.f%%'))

# %%
#pairplot
plt.show(sn.pairplot(df_poprua, hue="Gênero"))

# %% [markdown]
# ### Mapas Georeferenciados

# %% [markdown]
# Preparando o datafrema para montar o gráfico

# %%
from shapely.geometry import Point, LineString, Polygon

# %% [markdown]
# Primeiro vamos preparar a tabela para ela poder funcionar dentro do geodataframe

# %%
df_poprua[['Longitude','Latitude']]
# Out:
#       Longitude   Latitude
# 0    -43.634687 -22.917108
# 1    -43.558147 -22.901543
# 2    -43.558115 -22.901599
# 3    -43.555531 -22.904111
# 4    -43.563940 -22.907769
# ...         ...        ...
# 7267 -43.653160 -22.956898
# 7268 -43.653160 -22.956898
# 7269 -43.653160 -22.956898
# 7270 -43.653160 -22.956898
# 7271 -43.653160 -22.956898
#
# [7272 rows x 2 columns]

# %%
#Criando a tabela geometry
df_poprua['geometry'] = None

'''
Para o funcionamento correto do dataframe como um geodataframe, pela forma que o geopandas funciona,
é necessário criar uma tabela que tenha nela as coordenadas, Latitude e Longitude, como Point, para que,
desta forma, consiga-se 
'''

#Para cada linha dessa coluna geometry, serão acrescentadas as coordenadas Latitude e Longitude no formato Point
for index,row in df_poprua.iterrows():
    df_poprua.loc[index, 'geometry'] = Point(row.Longitude,row.Latitude)
    
display(df_poprua)
# Out:
# C:\Users\amori\anaconda3\envs\datamind\lib\site-packages\pandas\core\internals\managers.py:304: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   applied = getattr(b, f)(**kwargs)
#                        Chave_única                            ID  \
# 0                        Rua_10000                         Rua_2
# 1                        Rua_10001                         Rua_5
# 2                        Rua_10002                         Rua_6
# 3                        Rua_10003                         Rua_8
# 4                        Rua_10004                         Rua_9
# ...                            ...                           ...
# 7267  Unidade de acolhimento_17267  Comunidades Terapêuticas_262
# 7268  Unidade de acolhimento_17268  Comunidades Terapêuticas_263
# 7269  Unidade de acolhimento_17269  Comunidades Terapêuticas_264
# 7270  Unidade de acolhimento_17270  Comunidades Terapêuticas_265
# 7271  Unidade de acolhimento_17271  Comunidades Terapêuticas_266
#
#      Rua_Acolhimento  Local da coleta de dados  \
# 0                Rua                       Rua
# 1                Rua                       Rua
# 2                Rua                       Rua
# 3                Rua                       Rua
# 4                Rua                       Rua
# ...              ...                       ...
# 7267       Acolhidos  Comunidades terapêuticas
# 7268       Acolhidos  Comunidades terapêuticas
# 7269       Acolhidos  Comunidades terapêuticas
# 7270       Acolhidos  Comunidades terapêuticas
# 7271       Acolhidos  Comunidades terapêuticas
#
#            Unidade de Acolhimento/US      Método Instrumento de coleta  \
# 0                       Sem Resposta  Entrevista   Questionário normal
# 1                       Sem Resposta  Entrevista   Questionário normal
# 2                       Sem Resposta  Entrevista   Questionário normal
# 3                       Sem Resposta  Entrevista   Questionário normal
# 4                       Sem Resposta  Entrevista   Questionário normal
# ...                              ...         ...                   ...
# 7267  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7268  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7269  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7270  Instituto Revivendo com Cristo  Observação   Questionário normal
# 7271  Instituto Revivendo com Cristo  Observação   Questionário normal
#
#           Cod_setor          Turno          Data  ...  \
# 0            D1S21M          Manhã    26/10/2020  ...
# 1            D1S20M          Manhã    26/10/2020  ...
# 2            D1S20M          Manhã    26/10/2020  ...
# 3            D1S20M          Manhã    26/10/2020  ...
# 4            D1S20M          Manhã    26/10/2020  ...
# ...             ...            ...           ...  ...
# 7267  Não se aplica  Não se aplica  Sem Resposta  ...
# 7268  Não se aplica  Não se aplica  Sem Resposta  ...
# 7269  Não se aplica  Não se aplica  Sem Resposta  ...
# 7270  Não se aplica  Não se aplica  Sem Resposta  ...
# 7271  Não se aplica  Não se aplica  Sem Resposta  ...
#
#      Necessidade_sair_situação  Área de Planejamento  Nome do Bairro  \
# 0        Não quero sair da rua                  AP 5       Paciência
# 1                      Família                  AP 5    Campo Grande
# 2                      Moradia                  AP 5    Campo Grande
# 3        Não quero sair da rua                  AP 5    Campo Grande
# 4                        Outro                  AP 5    Campo Grande
# ...                        ...                   ...             ...
# 7267             Não se aplica                  AP 5       Guaratiba
# 7268             Não se aplica                  AP 5       Guaratiba
# 7269             Não se aplica                  AP 5       Guaratiba
# 7270             Não se aplica                  AP 5       Guaratiba
# 7271             Não se aplica                  AP 5       Guaratiba
#
#      Código da RP                  RP  Código da RA Região Administrativa  \
# 0             5.3    5.3 - Santa Cruz            19      XIX - SANTA CRUZ
# 1             5.2  5.2 - Campo Grande            18  XVIII - CAMPO GRANDE
# 2             5.2  5.2 - Campo Grande            18  XVIII - CAMPO GRANDE
# 3             5.2  5.2 - Campo Grande            18  XVIII - CAMPO GRANDE
# 4             5.2  5.2 - Campo Grande            18  XVIII - CAMPO GRANDE
# ...           ...                 ...           ...                   ...
# 7267          5.4     5.4 - Guaratiba            26      XXVI - GUARATIBA
# 7268          5.4     5.4 - Guaratiba            26      XXVI - GUARATIBA
# 7269          5.4     5.4 - Guaratiba            26      XXVI - GUARATIBA
# 7270          5.4     5.4 - Guaratiba            26      XXVI - GUARATIBA
# 7271          5.4     5.4 - Guaratiba            26      XXVI - GUARATIBA
#
#           Faixa etária Classificação idade  \
# 0              18 a 30              Adulto
# 1              31 a 49              Adulto
# 2              31 a 49              Adulto
# 3              50 a 59              Adulto
# 4              31 a 49              Adulto
# ...                ...                 ...
# 7267  Não identificada      Sem informação
# 7268  Não identificada      Sem informação
# 7269  Não identificada      Sem informação
# 7270  Não identificada      Sem informação
# 7271  Não identificada      Sem informação
#
#                                            geometry
# 0     POINT (-43.63468747867677 -22.91710790310234)
# 1                   POINT (-43.5581468 -22.9015435)
# 2                   POINT (-43.5581147 -22.9015987)
# 3                   POINT (-43.5555309 -22.9041105)
# 4                    POINT (-43.5639398 -22.907769)
# ...                                             ...
# 7267    POINT (-43.6531595624735 -22.9568976650272)
# 7268    POINT (-43.6531595624735 -22.9568976650272)
# 7269    POINT (-43.6531595624735 -22.9568976650272)
# 7270    POINT (-43.6531595624735 -22.9568976650272)
# 7271    POINT (-43.6531595624735 -22.9568976650272)
#
# [7272 rows x 137 columns]

# %%
#Criando o Geodataframe
geo_poprua = gpd.GeoDataFrame(df_poprua, geometry = 'geometry')
print(type(geo_poprua))#agoa sim nos temos um geodataframe
display(geo_poprua.head(5))#Mas note que a tabela continua normal... Legal né.
print(geo_poprua.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#   Chave_única     ID Rua_Acolhimento Local da coleta de dados  \
# 0   Rua_10000  Rua_2             Rua                      Rua
# 1   Rua_10001  Rua_5             Rua                      Rua
# 2   Rua_10002  Rua_6             Rua                      Rua
# 3   Rua_10003  Rua_8             Rua                      Rua
# 4   Rua_10004  Rua_9             Rua                      Rua
#
#   Unidade de Acolhimento/US      Método Instrumento de coleta Cod_setor  \
# 0              Sem Resposta  Entrevista   Questionário normal    D1S21M
# 1              Sem Resposta  Entrevista   Questionário normal    D1S20M
# 2              Sem Resposta  Entrevista   Questionário normal    D1S20M
# 3              Sem Resposta  Entrevista   Questionário normal    D1S20M
# 4              Sem Resposta  Entrevista   Questionário normal    D1S20M
#
#    Turno        Data  ... Necessidade_sair_situação  Área de Planejamento  \
# 0  Manhã  26/10/2020  ...     Não quero sair da rua                  AP 5
# 1  Manhã  26/10/2020  ...                   Família                  AP 5
# 2  Manhã  26/10/2020  ...                   Moradia                  AP 5
# 3  Manhã  26/10/2020  ...     Não quero sair da rua                  AP 5
# 4  Manhã  26/10/2020  ...                     Outro                  AP 5
#
#    Nome do Bairro Código da RP                  RP  Código da RA  \
# 0       Paciência          5.3    5.3 - Santa Cruz            19
# 1    Campo Grande          5.2  5.2 - Campo Grande            18
# 2    Campo Grande          5.2  5.2 - Campo Grande            18
# 3    Campo Grande          5.2  5.2 - Campo Grande            18
# 4    Campo Grande          5.2  5.2 - Campo Grande            18
#
#   Região Administrativa Faixa etária Classificação idade  \
# 0      XIX - SANTA CRUZ      18 a 30              Adulto
# 1  XVIII - CAMPO GRANDE      31 a 49              Adulto
# 2  XVIII - CAMPO GRANDE      31 a 49              Adulto
# 3  XVIII - CAMPO GRANDE      50 a 59              Adulto
# 4  XVIII - CAMPO GRANDE      31 a 49              Adulto
#
#                       geometry
# 0  POINT (-43.63469 -22.91711)
# 1  POINT (-43.55815 -22.90154)
# 2  POINT (-43.55811 -22.90160)
# 3  POINT (-43.55553 -22.90411)
# 4  POINT (-43.56394 -22.90777)
#
# [5 rows x 137 columns]
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 7272 entries, 0 to 7271
# Columns: 137 entries, Chave_única to geometry
# dtypes: float64(3), geometry(1), int64(2), object(131)
# memory usage: 7.6+ MB
# None

# %% [markdown]
# Preparando a geometria para o gráfico

# %%
plt.show(geo_poprua.plot())

# %%
muni_rj.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CD_MUN    1 non-null      object
#  1   NM_MUN    1 non-null      object
#  2   SIGLA     1 non-null      object
#  3   AREA_KM2  1 non-null      float64
#  4   geometry  1 non-null      geometry
# dtypes: float64(1), geometry(1), object(3)
# memory usage: 168.0+ bytes

# %% [markdown]
# Dados da região (Mapa) do Rio de Janeiro (Estado)

# %% [markdown]
# Unindo o (agora) GeoDataFrame à geometria

# %%
#Mapa do Município:
display(muni_rj.head(5))
plt.show((muni_rj.plot(figsize = (16, 14),facecolor = 'white', edgecolor = 'black')))
# Out:
#     CD_MUN          NM_MUN SIGLA  AREA_KM2  \
# 0  3304557  Rio de Janeiro    RJ  1200.329
#
#                                             geometry
# 0  MULTIPOLYGON (((-43.56883 -23.08162, -43.56886...

# %% [markdown]
# Corrigindo possiveis problemas da junção

# %%
#Transformando o mapa em poligono
poly_rio = muni_rj.iloc[0].geometry
display(poly_rio)
type(poly_rio)
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
geo_poprua2 = geo_poprua[geo_poprua.intersects(poly_rio)]

# %%
fig, ax = plt.subplots(figsize = (15,15))
plt.show(geo_poprua2.plot(ax=ax),muni_rj.plot(ax=ax, facecolor = "None", edgecolor = "black"))
